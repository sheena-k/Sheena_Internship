# %% [markdown]
# **Probelm Statement: A global financial company wants to develop an intelligent system employing data science and machine learning to automate the categorization of individuals into specific credit score brackets. Firstly, it seeks to alleviate the manual effort involved in credit assessment, optimizing operational processes. Secondly, it aims to enable more tailored financial services by precisely classifying customers based on their creditworthiness.**

# %% [markdown]
# **Goal: Banks and credit card companies calculate your credit score to determine your creditworthiness. It helps banks and credit card companies immediately to issue loans to customers with good creditworthiness.
# There are three credit scores that banks and credit card companies use to label their customers:
# Good,Standard,Poor . A person with a good credit score will get loans from any bank and financial institution. The credit scoring model evaluates various factors, including payment history, credit utilization, length of credit history, types of credit accounts, and recent credit inquiries.**

# %%
#Importing necessary python libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading dataset to python environment

# %%
df= pd.read_csv("credit.csv")

# %%
data=df.copy() #Copying dataset so that changes are not reflected in original dataset

# %%
data.head(20) #Displaying first few rows of dataset
# Out:
#       ID  Customer_ID  Month             Name   Age          SSN Occupation  \
# 0   5634         3392      1    Aaron Maashoh  23.0  821000265.0  Scientist
# 1   5635         3392      2    Aaron Maashoh  23.0  821000265.0  Scientist
# 2   5636         3392      3    Aaron Maashoh  23.0  821000265.0  Scientist
# 3   5637         3392      4    Aaron Maashoh  23.0  821000265.0  Scientist
# 4   5638         3392      5    Aaron Maashoh  23.0  821000265.0  Scientist
# 5   5639         3392      6    Aaron Maashoh  23.0  821000265.0  Scientist
# 6   5640         3392      7    Aaron Maashoh  23.0  821000265.0  Scientist
# 7   5641         3392      8    Aaron Maashoh  23.0  821000265.0  Scientist
# 8   5646         8625      1  Rick Rothackerj  28.0    4075839.0    Teacher
# 9   5647         8625      2  Rick Rothackerj  28.0    4075839.0    Teacher
# 10  5648         8625      3  Rick Rothackerj  28.0    4075839.0    Teacher
# 11  5649         8625      4  Rick Rothackerj  28.0    4075839.0    Teacher
# 12  5650         8625      5  Rick Rothackerj  28.0    4075839.0    Teacher
# 13  5651         8625      6  Rick Rothackerj  28.0    4075839.0    Teacher
# 14  5652         8625      7  Rick Rothackerj  28.0    4075839.0    Teacher
# 15  5653         8625      8  Rick Rothackerj  28.0    4075839.0    Teacher
# 16  5658        11708      1           Langep  34.0  486853974.0   Engineer
# 17  5659        11708      2           Langep  34.0  486853974.0   Engineer
# 18  5660        11708      3           Langep  34.0  486853974.0   Engineer
# 19  5661        11708      4           Langep  34.0  486853974.0   Engineer
#
#     Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0        19114.12            1824.843333                3.0  ...        Good
# 1        19114.12            1824.843333                3.0  ...        Good
# 2        19114.12            1824.843333                3.0  ...        Good
# 3        19114.12            1824.843333                3.0  ...        Good
# 4        19114.12            1824.843333                3.0  ...        Good
# 5        19114.12            1824.843333                3.0  ...        Good
# 6        19114.12            1824.843333                3.0  ...        Good
# 7        19114.12            1824.843333                3.0  ...        Good
# 8        34847.84            3037.986667                2.0  ...        Good
# 9        34847.84            3037.986667                2.0  ...        Good
# 10       34847.84            3037.986667                2.0  ...        Good
# 11       34847.84            3037.986667                2.0  ...        Good
# 12       34847.84            3037.986667                2.0  ...        Good
# 13       34847.84            3037.986667                2.0  ...        Good
# 14       34847.84            3037.986667                2.0  ...        Good
# 15       34847.84            3037.986667                2.0  ...        Good
# 16      143162.64           12187.220000                1.0  ...        Good
# 17      143162.64           12187.220000                1.0  ...        Good
# 18      143162.64           12187.220000                1.0  ...        Good
# 19      143162.64           12187.220000                1.0  ...        Good
#
#     Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 0             809.98                 26.822620              265.0
# 1             809.98                 31.944960              266.0
# 2             809.98                 28.609352              267.0
# 3             809.98                 31.377862              268.0
# 4             809.98                 24.797347              269.0
# 5             809.98                 27.262259              270.0
# 6             809.98                 22.537593              271.0
# 7             809.98                 23.933795              272.0
# 8             605.03                 24.464031              319.0
# 9             605.03                 38.550848              320.0
# 10            605.03                 33.224951              321.0
# 11            605.03                 39.182656              322.0
# 12            605.03                 34.977895              323.0
# 13            605.03                 33.381010              324.0
# 14            605.03                 31.131702              325.0
# 15            605.03                 32.933856              326.0
# 16           1303.01                 28.616735              213.0
# 17           1303.01                 41.702573              214.0
# 18           1303.01                 26.519815              215.0
# 19           1303.01                 39.501648              216.0
#
#     Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                      No            49.574949                21.465380
# 1                      No            49.574949                21.465380
# 2                      No            49.574949                21.465380
# 3                      No            49.574949                21.465380
# 4                      No            49.574949                21.465380
# 5                      No            49.574949                21.465380
# 6                      No            49.574949                21.465380
# 7                      No            49.574949                21.465380
# 8                      No            18.816215                39.684018
# 9                      No            18.816215                39.684018
# 10                     No            18.816215                39.684018
# 11                     No            18.816215                39.684018
# 12                     No            18.816215                39.684018
# 13                     No            18.816215                39.684018
# 14                     NM            18.816215                39.684018
# 15                     No            18.816215                39.684018
# 16                     No           246.992319               168.413703
# 17                     No           246.992319               168.413703
# 18                     No           246.992319               168.413703
# 19                     No           246.992319               168.413703
#
#                    Payment_Behaviour Monthly_Balance  Credit_Score
# 0    High_spent_Small_value_payments      312.494089          Good
# 1     Low_spent_Large_value_payments      284.629162          Good
# 2    Low_spent_Medium_value_payments      331.209863          Good
# 3     Low_spent_Small_value_payments      223.451310          Good
# 4   High_spent_Medium_value_payments      341.489231          Good
# 5   High_spent_Medium_value_payments      340.479212          Good
# 6     Low_spent_Small_value_payments      244.565317          Good
# 7   High_spent_Medium_value_payments      358.124168      Standard
# 8     Low_spent_Small_value_payments      470.690627      Standard
# 9    High_spent_Large_value_payments      484.591214          Good
# 10   High_spent_Large_value_payments      466.466476      Standard
# 11   Low_spent_Medium_value_payments      465.676224          Good
# 12    Low_spent_Small_value_payments      444.867032          Good
# 13   High_spent_Large_value_payments      481.505262          Good
# 14  High_spent_Medium_value_payments      464.880678          Good
# 15    Low_spent_Small_value_payments      356.078109          Good
# 16   High_spent_Small_value_payments     1043.315978          Good
# 17   High_spent_Small_value_payments      998.869297          Good
# 18   High_spent_Small_value_payments      715.741367          Good
# 19   Low_spent_Medium_value_payments      426.513411          Good
#
# [20 rows x 28 columns]

# %%
data.tail(20) #Displaying last few rows of dataset
# Out:
#            ID  Customer_ID  Month            Name   Age          SSN  \
# 99980  155602        44897      5  Chris Wickhamm  49.0  133167738.0
# 99981  155603        44897      6  Chris Wickhamm  50.0  133167738.0
# 99982  155604        44897      7  Chris Wickhamm  50.0  133167738.0
# 99983  155605        44897      8  Chris Wickhamm  50.0  133167738.0
# 99984  155610        34304      1  Sarah McBridec  28.0   31350942.0
# 99985  155611        34304      2  Sarah McBridec  28.0   31350942.0
# 99986  155612        34304      3  Sarah McBridec  28.0   31350942.0
# 99987  155613        34304      4  Sarah McBridec  28.0   31350942.0
# 99988  155614        34304      5  Sarah McBridec  28.0   31350942.0
# 99989  155615        34304      6  Sarah McBridec  28.0   31350942.0
# 99990  155616        34304      7  Sarah McBridec  28.0   31350942.0
# 99991  155617        34304      8  Sarah McBridec  29.0   31350942.0
# 99992  155622        37932      1           Nicks  24.0   78735990.0
# 99993  155623        37932      2           Nicks  25.0   78735990.0
# 99994  155624        37932      3           Nicks  25.0   78735990.0
# 99995  155625        37932      4           Nicks  25.0   78735990.0
# 99996  155626        37932      5           Nicks  25.0   78735990.0
# 99997  155627        37932      6           Nicks  25.0   78735990.0
# 99998  155628        37932      7           Nicks  25.0   78735990.0
# 99999  155629        37932      8           Nicks  25.0   78735990.0
#
#       Occupation  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# 99980     Writer       37188.10            3097.008333                1.0
# 99981     Writer       37188.10            3097.008333                1.0
# 99982     Writer       37188.10            3097.008333                1.0
# 99983     Writer       37188.10            3097.008333                1.0
# 99984  Architect       20002.88            1929.906667               10.0
# 99985  Architect       20002.88            1929.906667               10.0
# 99986  Architect       20002.88            1929.906667               10.0
# 99987  Architect       20002.88            1929.906667               10.0
# 99988  Architect       20002.88            1929.906667               10.0
# 99989  Architect       20002.88            1929.906667               10.0
# 99990  Architect       20002.88            1929.906667               10.0
# 99991  Architect       20002.88            1929.906667               10.0
# 99992   Mechanic       39628.99            3359.415833                4.0
# 99993   Mechanic       39628.99            3359.415833                4.0
# 99994   Mechanic       39628.99            3359.415833                4.0
# 99995   Mechanic       39628.99            3359.415833                4.0
# 99996   Mechanic       39628.99            3359.415833                4.0
# 99997   Mechanic       39628.99            3359.415833                4.0
# 99998   Mechanic       39628.99            3359.415833                4.0
# 99999   Mechanic       39628.99            3359.415833                4.0
#
#        ...  Credit_Mix  Outstanding_Debt  Credit_Utilization_Ratio  \
# 99980  ...        Good            620.64                 27.495263
# 99981  ...        Good            620.64                 37.753013
# 99982  ...        Good            620.64                 38.850680
# 99983  ...        Good            620.64                 39.300980
# 99984  ...         Bad           3571.70                 22.895966
# 99985  ...         Bad           3571.70                 39.772607
# 99986  ...         Bad           3571.70                 24.713861
# 99987  ...         Bad           3571.70                 30.614953
# 99988  ...         Bad           3571.70                 28.508250
# 99989  ...         Bad           3571.70                 33.359987
# 99990  ...         Bad           3571.70                 25.123535
# 99991  ...         Bad           3571.70                 37.140784
# 99992  ...        Good            502.38                 32.991333
# 99993  ...        Good            502.38                 29.135447
# 99994  ...        Good            502.38                 39.323569
# 99995  ...        Good            502.38                 34.663572
# 99996  ...        Good            502.38                 40.565631
# 99997  ...        Good            502.38                 41.255522
# 99998  ...        Good            502.38                 33.638208
# 99999  ...        Good            502.38                 34.192463
#
#       Credit_History_Age  Payment_of_Min_Amount  Total_EMI_per_month  \
# 99980              361.0                     No            84.205949
# 99981              362.0                     NM            84.205949
# 99982              363.0                     No            84.205949
# 99983              364.0                     No            84.205949
# 99984               68.0                    Yes            60.964772
# 99985               69.0                    Yes            60.964772
# 99986               70.0                    Yes            60.964772
# 99987               71.0                    Yes            60.964772
# 99988               72.0                    Yes            60.964772
# 99989               73.0                    Yes            60.964772
# 99990               74.0                    Yes            60.964772
# 99991               75.0                    Yes            60.964772
# 99992              375.0                     No            35.104023
# 99993              376.0                     No            35.104023
# 99994              377.0                     No            35.104023
# 99995              378.0                     No            35.104023
# 99996              379.0                     No            35.104023
# 99997              380.0                     No            35.104023
# 99998              381.0                     No            35.104023
# 99999              382.0                     No            35.104023
#
#        Amount_invested_monthly                 Payment_Behaviour  \
# 99980                42.935566    Low_spent_Small_value_payments
# 99981                42.935566    Low_spent_Small_value_payments
# 99982                42.935566    Low_spent_Small_value_payments
# 99983                42.935566  High_spent_Medium_value_payments
# 99984                34.662906   High_spent_Large_value_payments
# 99985                34.662906    Low_spent_Small_value_payments
# 99986                34.662906    Low_spent_Small_value_payments
# 99987                34.662906   High_spent_Large_value_payments
# 99988                34.662906    Low_spent_Small_value_payments
# 99989                34.662906    Low_spent_Small_value_payments
# 99990                34.662906    Low_spent_Large_value_payments
# 99991                34.662906   High_spent_Large_value_payments
# 99992                24.028477    Low_spent_Small_value_payments
# 99993                24.028477   Low_spent_Medium_value_payments
# 99994                24.028477  High_spent_Medium_value_payments
# 99995                24.028477   High_spent_Large_value_payments
# 99996                24.028477  High_spent_Medium_value_payments
# 99997                24.028477   High_spent_Large_value_payments
# 99998                24.028477    Low_spent_Large_value_payments
# 99999                24.028477  High_spent_Medium_value_payments
#
#       Monthly_Balance  Credit_Score
# 99980      396.997157      Standard
# 99981      368.154976          Good
# 99982      412.669312          Good
# 99983      432.559318          Good
# 99984      328.655224          Poor
# 99985      273.750662          Poor
# 99986      345.743101          Poor
# 99987      328.301277      Standard
# 99988      208.047884      Standard
# 99989      307.659291      Standard
# 99990      228.750392      Standard
# 99991      337.362988      Standard
# 99992      189.641080          Poor
# 99993      400.104466      Standard
# 99994      410.256158          Poor
# 99995      479.866228          Poor
# 99996      496.651610          Poor
# 99997      516.809083          Poor
# 99998      319.164979      Standard
# 99999      393.673696          Poor
#
# [20 rows x 28 columns]

# %%
data.shape #displaying the total columns and rows in dataset
# Out:
# (100000, 28)

# %%
data.columns #displaying each column features
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
data.info() #displaying baisc info like data types and Non -Null count of each features
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  float64
#  5   SSN                       100000 non-null  float64
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  float64
#  10  Num_Credit_Card           100000 non-null  float64
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  float64
#  13  Type_of_Loan              100000 non-null  object
#  14  Delay_from_due_date       100000 non-null  float64
#  15  Num_of_Delayed_Payment    100000 non-null  float64
#  16  Changed_Credit_Limit      100000 non-null  float64
#  17  Num_Credit_Inquiries      100000 non-null  float64
#  18  Credit_Mix                100000 non-null  object
#  19  Outstanding_Debt          100000 non-null  float64
#  20  Credit_Utilization_Ratio  100000 non-null  float64
#  21  Credit_History_Age        100000 non-null  float64
#  22  Payment_of_Min_Amount     100000 non-null  object
#  23  Total_EMI_per_month       100000 non-null  float64
#  24  Amount_invested_monthly   100000 non-null  float64
#  25  Payment_Behaviour         100000 non-null  object
#  26  Monthly_Balance           100000 non-null  float64
#  27  Credit_Score              100000 non-null  object
# dtypes: float64(18), int64(3), object(7)
# memory usage: 21.4+ MB

# %%
data.nunique() #displaying unique value counts in each feature
# Out:
# ID                          100000
# Customer_ID                  12500
# Month                            8
# Name                         10128
# Age                             43
# SSN                          12500
# Occupation                      15
# Annual_Income                12488
# Monthly_Inhand_Salary        13241
# Num_Bank_Accounts               12
# Num_Credit_Card                 12
# Interest_Rate                   34
# Num_of_Loan                     10
# Type_of_Loan                  6261
# Delay_from_due_date             63
# Num_of_Delayed_Payment          26
# Changed_Credit_Limit          3452
# Num_Credit_Inquiries            18
# Credit_Mix                       3
# Outstanding_Debt             12203
# Credit_Utilization_Ratio    100000
# Credit_History_Age             404
# Payment_of_Min_Amount            3
# Total_EMI_per_month          11890
# Amount_invested_monthly      12261
# Payment_Behaviour                6
# Monthly_Balance              98494
# Credit_Score                     3
# dtype: int64

# %%
data["Name"].value_counts() #value count of categorical feature "Name"
# Out:
# Jessicad              48
# Langep                48
# Stevex                48
# Vaughanl              40
# Ronald Groverk        40
#                       ..
# Breidthardtj           8
# Sven Egenterx          8
# Antonella Ciancioc     8
# Valentina Zan          8
# Nicks                  8
# Name: Name, Length: 10128, dtype: int64

# %%
data["Occupation"].value_counts() #value count of categorical feature "Occupation"
# Out:
# Lawyer           7096
# Engineer         6864
# Architect        6824
# Mechanic         6776
# Scientist        6744
# Accountant       6744
# Developer        6720
# Media_Manager    6720
# Teacher          6672
# Entrepreneur     6648
# Doctor           6568
# Journalist       6536
# Manager          6432
# Musician         6352
# Writer           6304
# Name: Occupation, dtype: int64

# %%
data["Type_of_Loan"].value_counts() # value count of categorical feature type of loan
# Out:
# No Data                                                                                                                               11408
# Not Specified                                                                                                                          1408
# Credit-Builder Loan                                                                                                                    1280
# Personal Loan                                                                                                                          1272
# Debt Consolidation Loan                                                                                                                1264
#                                                                                                                                       ...
# Not Specified, Mortgage Loan, Auto Loan, and Payday Loan                                                                                  8
# Payday Loan, Mortgage Loan, Debt Consolidation Loan, and Student Loan                                                                     8
# Debt Consolidation Loan, Auto Loan, Personal Loan, Debt Consolidation Loan, Student Loan, and Credit-Builder Loan                         8
# Student Loan, Auto Loan, Student Loan, Credit-Builder Loan, Home Equity Loan, Debt Consolidation Loan, and Debt Consolidation Loan        8
# Personal Loan, Auto Loan, Mortgage Loan, Student Loan, and Student Loan                                                                   8
# Name: Type_of_Loan, Length: 6261, dtype: int64

# %%
data["Credit_Mix"].value_counts() # value count of column feature Credit Mix
# Out:
# Standard    45848
# Good        30384
# Bad         23768
# Name: Credit_Mix, dtype: int64

# %%
data["Payment_of_Min_Amount"].value_counts() # value count of feature Payment of Minimum Amount
# Out:
# Yes    52326
# No     35667
# NM     12007
# Name: Payment_of_Min_Amount, dtype: int64

# %%
data["Payment_Behaviour"].value_counts() # value count of feature Payment behaviour
# Out:
# Low_spent_Small_value_payments      28616
# High_spent_Medium_value_payments    19738
# High_spent_Large_value_payments     14726
# Low_spent_Medium_value_payments     14399
# High_spent_Small_value_payments     11764
# Low_spent_Large_value_payments      10757
# Name: Payment_Behaviour, dtype: int64

# %%
data["Credit_Score"].value_counts() # value count of  target feature "credit score"
# Out:
# Standard    53174
# Poor        28998
# Good        17828
# Name: Credit_Score, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.describe() #Baisc descriptive statistics of Numerical features
# Out:
#                   ID    Customer_ID          Month            Age  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    80631.500000   25982.666640       4.500000      33.316340
# std     43301.486619   14340.543051       2.291299      10.764812
# min      5634.000000    1006.000000       1.000000      14.000000
# 25%     43132.750000   13664.500000       2.750000      24.000000
# 50%     80631.500000   25777.000000       4.500000      33.000000
# 75%    118130.250000   38385.000000       6.250000      42.000000
# max    155629.000000   50999.000000       8.000000      56.000000
#
#                 SSN  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  1.000000e+05  100000.000000          100000.000000      100000.000000
# mean   5.004617e+08   50505.123449            4197.270835           5.368820
# std    2.908267e+08   38299.422093            3186.432497           2.593314
# min    8.134900e+04    7005.930000             303.645417           0.000000
# 25%    2.451686e+08   19342.972500            1626.594167           3.000000
# 50%    5.006886e+08   36999.705000            3095.905000           5.000000
# 75%    7.560027e+08   71683.470000            5957.715000           7.000000
# max    9.999934e+08  179987.280000           15204.633333          11.000000
#
#        Num_Credit_Card  Interest_Rate  ...  Delay_from_due_date  \
# count    100000.000000   100000.00000  ...         100000.00000
# mean          5.533570       14.53208  ...             21.08141
# std           2.067098        8.74133  ...             14.80456
# min           0.000000        1.00000  ...              0.00000
# 25%           4.000000        7.00000  ...             10.00000
# 50%           5.000000       13.00000  ...             18.00000
# 75%           7.000000       20.00000  ...             28.00000
# max          11.000000       34.00000  ...             62.00000
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Num_Credit_Inquiries  \
# count           100000.000000         100000.000000         100000.000000
# mean                13.313120             10.470323              5.798250
# std                  6.237166              6.609481              3.867826
# min                  0.000000              0.500000              0.000000
# 25%                  9.000000              5.380000              3.000000
# 50%                 14.000000              9.400000              5.000000
# 75%                 18.000000             14.850000              8.000000
# max                 25.000000             29.980000             17.000000
#
#        Outstanding_Debt  Credit_Utilization_Ratio  Credit_History_Age  \
# count     100000.000000             100000.000000       100000.000000
# mean        1426.220376                 32.285173          221.220460
# std         1155.129026                  5.116875           99.680716
# min            0.230000                 20.000000            1.000000
# 25%          566.072500                 28.052567          144.000000
# 50%         1166.155000                 32.305784          219.000000
# 75%         1945.962500                 36.496663          302.000000
# max         4998.070000                 50.000000          404.000000
#
#        Total_EMI_per_month  Amount_invested_monthly  Monthly_Balance
# count        100000.000000            100000.000000    100000.000000
# mean            107.699208                55.101315       392.697586
# std             132.267056                39.006932       201.652719
# min               0.000000                 0.000000         0.007760
# 25%              29.268886                27.959111       267.615983
# 50%              66.462304                45.156550       333.865366
# 75%             147.392573                71.295797       463.215683
# max            1779.103254               434.191089      1183.930696
#
# [8 rows x 21 columns]

# %%
data.describe(include ="all") ##Baisc descriptive statistics including all , both categorical and numerical features
# Out:
#                    ID    Customer_ID          Month      Name            Age  \
# count   100000.000000  100000.000000  100000.000000    100000  100000.000000
# unique            NaN            NaN            NaN     10128            NaN
# top               NaN            NaN            NaN  Jessicad            NaN
# freq              NaN            NaN            NaN        48            NaN
# mean     80631.500000   25982.666640       4.500000       NaN      33.316340
# std      43301.486619   14340.543051       2.291299       NaN      10.764812
# min       5634.000000    1006.000000       1.000000       NaN      14.000000
# 25%      43132.750000   13664.500000       2.750000       NaN      24.000000
# 50%      80631.500000   25777.000000       4.500000       NaN      33.000000
# 75%     118130.250000   38385.000000       6.250000       NaN      42.000000
# max     155629.000000   50999.000000       8.000000       NaN      56.000000
#
#                  SSN Occupation  Annual_Income  Monthly_Inhand_Salary  \
# count   1.000000e+05     100000  100000.000000          100000.000000
# unique           NaN         15            NaN                    NaN
# top              NaN     Lawyer            NaN                    NaN
# freq             NaN       7096            NaN                    NaN
# mean    5.004617e+08        NaN   50505.123449            4197.270835
# std     2.908267e+08        NaN   38299.422093            3186.432497
# min     8.134900e+04        NaN    7005.930000             303.645417
# 25%     2.451686e+08        NaN   19342.972500            1626.594167
# 50%     5.006886e+08        NaN   36999.705000            3095.905000
# 75%     7.560027e+08        NaN   71683.470000            5957.715000
# max     9.999934e+08        NaN  179987.280000           15204.633333
#
#         Num_Bank_Accounts  ...  Credit_Mix  Outstanding_Debt  \
# count       100000.000000  ...      100000     100000.000000
# unique                NaN  ...           3               NaN
# top                   NaN  ...    Standard               NaN
# freq                  NaN  ...       45848               NaN
# mean             5.368820  ...         NaN       1426.220376
# std              2.593314  ...         NaN       1155.129026
# min              0.000000  ...         NaN          0.230000
# 25%              3.000000  ...         NaN        566.072500
# 50%              5.000000  ...         NaN       1166.155000
# 75%              7.000000  ...         NaN       1945.962500
# max             11.000000  ...         NaN       4998.070000
#
#         Credit_Utilization_Ratio Credit_History_Age  Payment_of_Min_Amount  \
# count              100000.000000      100000.000000                 100000
# unique                       NaN                NaN                      3
# top                          NaN                NaN                    Yes
# freq                         NaN                NaN                  52326
# mean                   32.285173         221.220460                    NaN
# std                     5.116875          99.680716                    NaN
# min                    20.000000           1.000000                    NaN
# 25%                    28.052567         144.000000                    NaN
# 50%                    32.305784         219.000000                    NaN
# 75%                    36.496663         302.000000                    NaN
# max                    50.000000         404.000000                    NaN
#
#         Total_EMI_per_month  Amount_invested_monthly  \
# count         100000.000000            100000.000000
# unique                  NaN                      NaN
# top                     NaN                      NaN
# freq                    NaN                      NaN
# mean             107.699208                55.101315
# std              132.267056                39.006932
# min                0.000000                 0.000000
# 25%               29.268886                27.959111
# 50%               66.462304                45.156550
# 75%              147.392573                71.295797
# max             1779.103254               434.191089
#
#                      Payment_Behaviour Monthly_Balance  Credit_Score
# count                           100000   100000.000000        100000
# unique                               6             NaN             3
# top     Low_spent_Small_value_payments             NaN      Standard
# freq                             28616             NaN         53174
# mean                               NaN      392.697586           NaN
# std                                NaN      201.652719           NaN
# min                                NaN        0.007760           NaN
# 25%                                NaN      267.615983           NaN
# 50%                                NaN      333.865366           NaN
# 75%                                NaN      463.215683           NaN
# max                                NaN     1183.930696           NaN
#
# [11 rows x 28 columns]

# %% [markdown]
# **Upon initial inspection, it was found that the dataset has 1,00,000 row entries and 28 column features. There are 27 predictor variables, both categorical and numerical variables and a target variable named “credit score” which is categorical. There are three credit scores that banks and credit card companies use to label their customers: good, standard and bad. Out of the 27 predictor variables, six are found to be categorical character variables, and rest are numerical variables. From inspecting statistical summary, it is found that the dataset doesn’t have any null values and genuine outliers.**

# %%
data[['Num_Bank_Accounts','Num_Credit_Card','Interest_Rate','Num_of_Loan','Type_of_Loan']]
# Out:
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                    3.0              4.0            3.0          4.0
# 1                    3.0              4.0            3.0          4.0
# 2                    3.0              4.0            3.0          4.0
# 3                    3.0              4.0            3.0          4.0
# 4                    3.0              4.0            3.0          4.0
# ...                  ...              ...            ...          ...
# 99995                4.0              6.0            7.0          2.0
# 99996                4.0              6.0            7.0          2.0
# 99997                4.0              6.0            7.0          2.0
# 99998                4.0              6.0            7.0          2.0
# 99999                4.0              6.0            7.0          2.0
#
#                                             Type_of_Loan
# 0      Auto Loan, Credit-Builder Loan, Personal Loan,...
# 1      Auto Loan, Credit-Builder Loan, Personal Loan,...
# 2      Auto Loan, Credit-Builder Loan, Personal Loan,...
# 3      Auto Loan, Credit-Builder Loan, Personal Loan,...
# 4      Auto Loan, Credit-Builder Loan, Personal Loan,...
# ...                                                  ...
# 99995                        Auto Loan, and Student Loan
# 99996                        Auto Loan, and Student Loan
# 99997                        Auto Loan, and Student Loan
# 99998                        Auto Loan, and Student Loan
# 99999                        Auto Loan, and Student Loan
#
# [100000 rows x 5 columns]

# %% [markdown]
# # Python Type conversion

# %%
data["Age"] = data["Age"].astype(int) 
data["Num_of_Loan"] = data["Num_of_Loan"].astype(int)
data["Num_Bank_Accounts"] =data["Num_Bank_Accounts"].astype(int)
data["Credit_History_Age"] = data["Credit_History_Age"].astype(int)
data["SSN"] = data["SSN"].astype(int)
data["Num_Credit_Inquiries"] = data["Num_Credit_Inquiries"].astype(int)
data["Num_Credit_Card"] = data["Num_Credit_Card"].astype(int)
data["Delay_from_due_date"] = data["Delay_from_due_date"].astype(int)
data["Num_of_Delayed_Payment"] = data["Num_of_Delayed_Payment"].astype(int)
data["Changed_Credit_Limit"] = data["Changed_Credit_Limit"].astype(int)

# %%
data.info() # basic info after type conversion
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  int64
#  1   Customer_ID               100000 non-null  int64
#  2   Month                     100000 non-null  int64
#  3   Name                      100000 non-null  object
#  4   Age                       100000 non-null  int32
#  5   SSN                       100000 non-null  int32
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  float64
#  8   Monthly_Inhand_Salary     100000 non-null  float64
#  9   Num_Bank_Accounts         100000 non-null  int32
#  10  Num_Credit_Card           100000 non-null  int32
#  11  Interest_Rate             100000 non-null  float64
#  12  Num_of_Loan               100000 non-null  int32
#  13  Type_of_Loan              100000 non-null  object
#  14  Delay_from_due_date       100000 non-null  int32
#  15  Num_of_Delayed_Payment    100000 non-null  int32
#  16  Changed_Credit_Limit      100000 non-null  int32
#  17  Num_Credit_Inquiries      100000 non-null  int32
#  18  Credit_Mix                100000 non-null  object
#  19  Outstanding_Debt          100000 non-null  float64
#  20  Credit_Utilization_Ratio  100000 non-null  float64
#  21  Credit_History_Age        100000 non-null  int32
#  22  Payment_of_Min_Amount     100000 non-null  object
#  23  Total_EMI_per_month       100000 non-null  float64
#  24  Amount_invested_monthly   100000 non-null  float64
#  25  Payment_Behaviour         100000 non-null  object
#  26  Monthly_Balance           100000 non-null  float64
#  27  Credit_Score              100000 non-null  object
# dtypes: float64(8), int32(10), int64(3), object(7)
# memory usage: 17.5+ MB

# %%
data.head()
# Out:
#      ID  Customer_ID  Month           Name  Age        SSN Occupation  \
# 0  5634         3392      1  Aaron Maashoh   23  821000265  Scientist
# 1  5635         3392      2  Aaron Maashoh   23  821000265  Scientist
# 2  5636         3392      3  Aaron Maashoh   23  821000265  Scientist
# 3  5637         3392      4  Aaron Maashoh   23  821000265  Scientist
# 4  5638         3392      5  Aaron Maashoh   23  821000265  Scientist
#
#    Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0       19114.12            1824.843333                  3  ...        Good
# 1       19114.12            1824.843333                  3  ...        Good
# 2       19114.12            1824.843333                  3  ...        Good
# 3       19114.12            1824.843333                  3  ...        Good
# 4       19114.12            1824.843333                  3  ...        Good
#
#    Outstanding_Debt  Credit_Utilization_Ratio Credit_History_Age  \
# 0            809.98                 26.822620                265
# 1            809.98                 31.944960                266
# 2            809.98                 28.609352                267
# 3            809.98                 31.377862                268
# 4            809.98                 24.797347                269
#
#    Payment_of_Min_Amount  Total_EMI_per_month  Amount_invested_monthly  \
# 0                     No            49.574949                 21.46538
# 1                     No            49.574949                 21.46538
# 2                     No            49.574949                 21.46538
# 3                     No            49.574949                 21.46538
# 4                     No            49.574949                 21.46538
#
#                   Payment_Behaviour Monthly_Balance  Credit_Score
# 0   High_spent_Small_value_payments      312.494089          Good
# 1    Low_spent_Large_value_payments      284.629162          Good
# 2   Low_spent_Medium_value_payments      331.209863          Good
# 3    Low_spent_Small_value_payments      223.451310          Good
# 4  High_spent_Medium_value_payments      341.489231          Good
#
# [5 rows x 28 columns]

# %%
data[["Num_Bank_Accounts","Num_Credit_Card"]]
# Out:
#        Num_Bank_Accounts  Num_Credit_Card
# 0                      3                4
# 1                      3                4
# 2                      3                4
# 3                      3                4
# 4                      3                4
# ...                  ...              ...
# 99995                  4                6
# 99996                  4                6
# 99997                  4                6
# 99998                  4                6
# 99999                  4                6
#
# [100000 rows x 2 columns]

# %%
data["Num_Bank_Accounts"].value_counts()
# Out:
# 6     13175
# 7     12999
# 8     12940
# 4     12343
# 5     12298
# 3     12107
# 9      5503
# 10     5329
# 1      4540
# 0      4417
# 2      4340
# 11        9
# Name: Num_Bank_Accounts, dtype: int64

# %%
data["Num_Credit_Card"].value_counts()
# Out:
# 5     18903
# 7     17024
# 6     16932
# 4     14362
# 3     13560
# 8      5073
# 10     4962
# 9      4753
# 2      2196
# 1      2185
# 11       36
# 0        14
# Name: Num_Credit_Card, dtype: int64

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
data['Credit_Score'].value_counts().plot.bar(title ="Credit Score") #Target feature
# Out:
# <Axes: title={'center': 'Credit Score'}>

# %%
fig =plt.figure(figsize=(10,7))
explode =[0.01,0.01,0.01]
plt.pie(data['Credit_Score'].value_counts(),explode=explode,autopct="%.3f",labels=["Standard","Good","Poor"])
plt.title("Credit Score")
# Out:
# Text(0.5, 1.0, 'Credit Score')

# %% [markdown]
# **The categorical feature is labelled into Standard, Poor and Good.**
#
# **Standard :53174**
#
# **Poor     :28998**
#
# **Good     :17828**

# %% [markdown]
# **from above dataset is imbalanced. Hence it is recommended to up-sample the data.**

# %%
data["Occupation"].value_counts().plot.bar(figsize=(20,10), title= "Occupation",color='c')  #Categorical feature "Occupation"
# Out:
# <Axes: title={'center': 'Occupation'}>

# %%
data['Credit_Mix'].value_counts().plot.bar(title ="Credit Mix")
# Out:
# <Axes: title={'center': 'Credit Mix'}>

# %%
data["Payment_of_Min_Amount"].value_counts().plot.bar(figsize=(20,10), title= "Payment_of_Min_Amount")
#Categorical feature Payment of Minimum amount
# Out:
# <Axes: title={'center': 'Payment_of_Min_Amount'}>

# %%
data["Payment_Behaviour"].value_counts().plot.bar(figsize=(20,10), title= "Payment_Behaviour")
#Categorical feature Payment Behaviour
# Out:
# <Axes: title={'center': 'Payment_Behaviour'}>

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
fig_PA= sns.countplot(data=data,x="Payment_of_Min_Amount", hue="Credit_Score",order=data['Payment_of_Min_Amount'].value_counts().index)
plt.xticks(rotation=90)
plt.title("Payment_of_Min_Amount v/s Credit Score",c="k")
plt.xlabel("Payment_of_Min_Amount",c="c")
plt.ylabel("Credit_Score",c="g")
plt.show(fig_PA)

# %%
fig_PB =sns.countplot(data=data,x="Payment_Behaviour", hue="Credit_Score",order=data['Payment_Behaviour'].value_counts().index)
plt.xticks(rotation=90)
plt.title("Payment_Behaviour v/s Credit Score",c="k")
plt.xlabel("Payment_Behaviour",c="c")
plt.ylabel("Credit_Score",c="g")
plt.show(fig_PB)

# %%
fig_PB =sns.countplot(data=data,x="Credit_Mix", hue="Credit_Score",order=data['Credit_Mix'].value_counts().index)
plt.xticks(rotation=90)
plt.title("Credit_Mix v/s Credit Score",c="k")
plt.xlabel("Credit_Mix",c="c")
plt.ylabel("Credit_Score",c="g")
plt.show(fig_PB)

# %%
fig_occ = sns.countplot(x="Occupation",data=data,order=data['Occupation'].value_counts().index)

plt.xticks(rotation=90)
plt.title("Occupation v/s Credit Score",c="k")
plt.xlabel("Occupation")
plt.ylabel("Credit_Score")
plt.figure(figsize=(50,30))
plt.show(fig_occ)

# %% [markdown]
# **The Occupation is labelled into 15 different profession and it is interpreted that there is no much difference in the credit scores among all occupations mentioned in the data.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Month", y="Credit_Score", data=data)

# %% [markdown]
# **from above the feature month doesnot have significant effect on target feature Credit Score.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Annual_Income", y="Credit_Score", data=data)

# %% [markdown]
# **the more you earn annually, the better your credit score**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Num_Bank_Accounts", y="Credit_Score", data=data)

# %% [markdown]
# **Having more bank account is not good for having a good credit score. A person should have 2 to 3 bank accounts only. So having more bank accounts doesn’t positively impact credit scores.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Num_Credit_Card", y="Credit_Score", data=data)

# %% [markdown]
# **Having more credit card is not good for having a good credit score. A person should have 4 to 5 credit card only. So having more credit card doesn’t positively impact credit scores.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Num_of_Loan", y="Credit_Score", data=data)

# %% [markdown]
# **Having more than 3 loans at a time doesnot provide a good credit score, it will negatively impact your credit scores.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Delay_from_due_date", y="Credit_Score", data=data)

# %% [markdown]
# **customer can delay your credit card payment 5 – 17 days from the due date. Delaying payments for more than 17 days from the due date will impact your credit scores negatively.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Num_of_Delayed_Payment", y="Credit_Score", data=data)

# %% [markdown]
# **customer can delay number of credit card payment 4 - 14 times. Delaying payments for more than 14 times will impact your credit scores negatively.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Outstanding_Debt", y="Credit_Score", data=data)

# %% [markdown]
# **An outstanding debt of amount 300 – 1100 will not affect your credit scores. But always having a debt of more than amount 1100 will affect credit scores or not.**

# %%
data["Changed_Credit_Limit"]
# Out:
# 0        11
# 1        11
# 2        11
# 3         6
# 4        11
#          ..
# 99995    11
# 99996    11
# 99997    11
# 99998    11
# 99999    11
# Name: Changed_Credit_Limit, Length: 100000, dtype: int32

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Changed_Credit_Limit", y="Credit_Score", data=data)

# %% [markdown]
# **A Changed Credit Limit of $ 3 - $ 6 is favorable to your credit scores. But having credit limit of above $ 6 is not favorable.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Credit_Utilization_Ratio", y="Credit_Score", data=data)

# %% [markdown]
# **The Credit utilization ratio means your total debt divided by your total available credit. According to the above figure, your credit utilization ratio doesn’t affect your credit scores.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Credit_History_Age", y="Credit_Score", data=data)

# %% [markdown]
# **having a long credit history result in better credit score.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Total_EMI_per_month", y="Credit_Score", data=data)

# %% [markdown]
# **The number of EMIs you are paying in a month doesn’t affect much on credit scores.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Amount_invested_monthly", y="Credit_Score", data=data)

# %% [markdown]
# **the amount of money you invest monthly doesn’t affect your credit scores a lot.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Monthly_Balance", y="Credit_Score", data=data)

# %% [markdown]
# **having a high monthly balance in your account at the end of the month is good for your credit scores. A monthly balance of salary less than 250 is bad for credit scores.**

# %%
sns.set_style("whitegrid")
ax = sns.boxplot(x="Monthly_Inhand_Salary", y="Credit_Score", data=data)

# %% [markdown]
# **having the more monthly in-hand salary you earn, the better your credit score will become.**

# %%
sns.set_style("whitegrid")

# %%
ax= sns.boxplot(x="Interest_Rate",y="Credit_Score",data=data)

# %% [markdown]
# **If the interest rate is 4 – 12.5%, the credit score is good. Having an interest rate of more than 15% is bad for your credit scores.**

# %%
rows_drop = data[data["Credit_Score"]=="Standard"].head(25000).index
data =data.drop(rows_drop)

# %%
rows_drop2 = data[data["Credit_Score"]=="Poor"].head(10000).index
data =data.drop(rows_drop2)

# %%
#outlier detection annual income 
q1_ai = np.percentile(data['Annual_Income'],25,method="midpoint")
q2_ai = np.percentile(data['Annual_Income'],50,method="midpoint")
q3_ai = np.percentile(data['Annual_Income'],75,method="midpoint")
iqr = q3_ai- q1_ai
outlier_ai=[]
up_lim_ai = q3_ai+ 1.5*iqr
low_lim_ai = q1_ai-1.5*iqr
for x in data['Annual_Income']:
    if (x<low_lim_ai) or (x>up_lim_ai):
        outlier_ai.append(x)
ind1 = data["Annual_Income"] > up_lim_ai
index_list1 = data.loc[ind1].index.tolist()
data =data.drop(index_list1)

# %%
#outlier detection monthly balance
q1_mb = np.percentile(data["Monthly_Balance"],25,method="midpoint")
q2_mb = np.percentile(data['Monthly_Balance'],50,method="midpoint")
q3_mb = np.percentile(data['Monthly_Balance'],75,method="midpoint")
iqr_mb = q3_mb- q1_mb
outlier_mb=[]
up_lim_mb = q3_mb+ 1.5*iqr_mb
low_lim_mb= q1_mb-1.5*iqr_mb
for x in data['Monthly_Balance']:
    if (x<low_lim_mb) or (x>up_lim_mb):
        outlier_mb.append(x)
ind3 = data["Monthly_Balance"] > up_lim_mb
index_list3 = data.loc[ind3].index.tolist()
data =data.drop(index_list3)

# %%
data.shape
# Out:
# (59156, 28)

# %%
# Correlation matrix among features
corr = data.corr()
plt.figure(figsize=(25,10))
sns.heatmap(corr,annot=True,fmt='.2')
# Out:
# C:\Users\skshe\AppData\Local\Temp\ipykernel_7652\1733382404.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()
# <Axes: >

# %% [markdown]
# **After performing EDA, Some irrelevant features like ID, Customer_ID,Month, Type_of_loan, Amount_invested_monthy, credit utilization ratio are dropped.**

# %%
train=data.drop(["ID","Customer_ID","Name","Month","Type_of_Loan","Occupation","Amount_invested_monthly","Credit_Utilization_Ratio"],axis=1) 
train
# Out:
#        Age        SSN  Annual_Income  Monthly_Inhand_Salary  \
# 0       23  821000265       19114.12            1824.843333
# 1       23  821000265       19114.12            1824.843333
# 2       23  821000265       19114.12            1824.843333
# 3       23  821000265       19114.12            1824.843333
# 4       23  821000265       19114.12            1824.843333
# ...    ...        ...            ...                    ...
# 99995   25   78735990       39628.99            3359.415833
# 99996   25   78735990       39628.99            3359.415833
# 99997   25   78735990       39628.99            3359.415833
# 99998   25   78735990       39628.99            3359.415833
# 99999   25   78735990       39628.99            3359.415833
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# 0                      3                4            3.0            4
# 1                      3                4            3.0            4
# 2                      3                4            3.0            4
# 3                      3                4            3.0            4
# 4                      3                4            3.0            4
# ...                  ...              ...            ...          ...
# 99995                  4                6            7.0            2
# 99996                  4                6            7.0            2
# 99997                  4                6            7.0            2
# 99998                  4                6            7.0            2
# 99999                  4                6            7.0            2
#
#        Delay_from_due_date  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# 0                        3                       7                    11
# 1                        3                       4                    11
# 2                        3                       7                    11
# 3                        5                       4                     6
# 4                        6                       4                    11
# ...                    ...                     ...                   ...
# 99995                   23                       7                    11
# 99996                   18                       7                    11
# 99997                   27                       6                    11
# 99998                   20                       6                    11
# 99999                   18                       6                    11
#
#        Num_Credit_Inquiries Credit_Mix  Outstanding_Debt  Credit_History_Age  \
# 0                         4       Good            809.98                 265
# 1                         4       Good            809.98                 266
# 2                         4       Good            809.98                 267
# 3                         4       Good            809.98                 268
# 4                         4       Good            809.98                 269
# ...                     ...        ...               ...                 ...
# 99995                     3       Good            502.38                 378
# 99996                     3       Good            502.38                 379
# 99997                     3       Good            502.38                 380
# 99998                     3       Good            502.38                 381
# 99999                     3       Good            502.38                 382
#
#       Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                        No            49.574949
# 1                        No            49.574949
# 2                        No            49.574949
# 3                        No            49.574949
# 4                        No            49.574949
# ...                     ...                  ...
# 99995                    No            35.104023
# 99996                    No            35.104023
# 99997                    No            35.104023
# 99998                    No            35.104023
# 99999                    No            35.104023
#
#                       Payment_Behaviour  Monthly_Balance Credit_Score
# 0       High_spent_Small_value_payments       312.494089         Good
# 1        Low_spent_Large_value_payments       284.629162         Good
# 2       Low_spent_Medium_value_payments       331.209863         Good
# 3        Low_spent_Small_value_payments       223.451310         Good
# 4      High_spent_Medium_value_payments       341.489231         Good
# ...                                 ...              ...          ...
# 99995   High_spent_Large_value_payments       479.866228         Poor
# 99996  High_spent_Medium_value_payments       496.651610         Poor
# 99997   High_spent_Large_value_payments       516.809083         Poor
# 99998    Low_spent_Large_value_payments       319.164979     Standard
# 99999  High_spent_Medium_value_payments       393.673696         Poor
#
# [59156 rows x 20 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59156 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     59156 non-null  int32
#  1   SSN                     59156 non-null  int32
#  2   Annual_Income           59156 non-null  float64
#  3   Monthly_Inhand_Salary   59156 non-null  float64
#  4   Num_Bank_Accounts       59156 non-null  int32
#  5   Num_Credit_Card         59156 non-null  int32
#  6   Interest_Rate           59156 non-null  float64
#  7   Num_of_Loan             59156 non-null  int32
#  8   Delay_from_due_date     59156 non-null  int32
#  9   Num_of_Delayed_Payment  59156 non-null  int32
#  10  Changed_Credit_Limit    59156 non-null  int32
#  11  Num_Credit_Inquiries    59156 non-null  int32
#  12  Credit_Mix              59156 non-null  object
#  13  Outstanding_Debt        59156 non-null  float64
#  14  Credit_History_Age      59156 non-null  int32
#  15  Payment_of_Min_Amount   59156 non-null  object
#  16  Total_EMI_per_month     59156 non-null  float64
#  17  Payment_Behaviour       59156 non-null  object
#  18  Monthly_Balance         59156 non-null  float64
#  19  Credit_Score            59156 non-null  object
# dtypes: float64(6), int32(10), object(4)
# memory usage: 7.2+ MB

# %% [markdown]
# # Encoding of Data

# %%
from sklearn.preprocessing import LabelEncoder #preprocess the data

# %%
le= LabelEncoder()

# %%
train["Credit_Score"] = le.fit_transform(train["Credit_Score"]) #label Encoding

# %%
train["Payment_Behaviour"] = le.fit_transform(train["Payment_Behaviour"])

# %%
train["Payment_of_Min_Amount"] = le.fit_transform(train["Payment_of_Min_Amount"])

# %%
train["Credit_Mix"] = le.fit_transform(train["Credit_Mix"])

# %%
train["Credit_Score"].value_counts()
# Out:
# 2    25804
# 1    18245
# 0    15107
# Name: Credit_Score, dtype: int64

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59156 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     59156 non-null  int32
#  1   SSN                     59156 non-null  int32
#  2   Annual_Income           59156 non-null  float64
#  3   Monthly_Inhand_Salary   59156 non-null  float64
#  4   Num_Bank_Accounts       59156 non-null  int32
#  5   Num_Credit_Card         59156 non-null  int32
#  6   Interest_Rate           59156 non-null  float64
#  7   Num_of_Loan             59156 non-null  int32
#  8   Delay_from_due_date     59156 non-null  int32
#  9   Num_of_Delayed_Payment  59156 non-null  int32
#  10  Changed_Credit_Limit    59156 non-null  int32
#  11  Num_Credit_Inquiries    59156 non-null  int32
#  12  Credit_Mix              59156 non-null  int32
#  13  Outstanding_Debt        59156 non-null  float64
#  14  Credit_History_Age      59156 non-null  int32
#  15  Payment_of_Min_Amount   59156 non-null  int32
#  16  Total_EMI_per_month     59156 non-null  float64
#  17  Payment_Behaviour       59156 non-null  int32
#  18  Monthly_Balance         59156 non-null  float64
#  19  Credit_Score            59156 non-null  int32
# dtypes: float64(6), int32(14)
# memory usage: 6.3 MB

# %%
corr = train.corr() #correlation matrix after encoding of data to get insights on both categorical values and numerical values.
plt.figure(figsize=(25,10))
sns.heatmap(corr,annot=True,fmt='.2')
# Out:
# <Axes: >

# %% [markdown]
# **from above correlation matrix Annual_Income, Monthly_Inhand_Salary are highly positively correlated, Hence retaining Annual_Income the Monthly_Inhand_Salary is dropped.**

# %%
X = train.drop(["Credit_Score","Monthly_Inhand_Salary"],axis=1)
Y = pd.DataFrame(train["Credit_Score"])  
Y
# Out:
#        Credit_Score
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 99995             1
# 99996             1
# 99997             1
# 99998             2
# 99999             1
#
# [59156 rows x 1 columns]

# %% [markdown]
# # Up-sampling of data

# %%
from imblearn.over_sampling import SMOTE #importing necessary libraries to mitigate the imbalanced data.

# %%
smote = SMOTE()
X,Y = smote.fit_resample(X,Y) #over-sampling the data.

# %%
t = Y['Credit_Score'].value_counts()  
plt.figure(figsize=(6,4))
sns.barplot(t.values,alpha=0.8)
t.plot.bar()
plt.ylabel('Number of Data', fontsize=12)
plt.xlabel('target', fontsize=9)
plt.xticks(rotation=90)
print(t)
plt.show()
# Out:
# 0    25804
# 1    25804
# 2    25804
# Name: Credit_Score, dtype: int64

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler #Perfrom MinMax Preprocessing

# %%
scaler_x = MinMaxScaler()
X_scale= scaler_x.fit_transform(X)
#rescaling the range of features to scale the range in [0, 1] or [−1, 1].

# %%
X_scale
# Out:
# array([[0.21428571, 0.8209911 , 0.08285239, ..., 0.02792955, 0.4       ,
#         0.41217101],
#        [0.21428571, 0.8209911 , 0.08285239, ..., 0.02792955, 0.6       ,
#         0.37541703],
#        [0.21428571, 0.8209911 , 0.08285239, ..., 0.02792955, 0.8       ,
#         0.43685721],
#        ...,
#        [0.85714286, 0.43340534, 0.16407616, ..., 0.01974566, 0.4       ,
#         0.51150256],
#        [0.57142857, 0.31897299, 0.09071972, ..., 0.03178463, 0.2       ,
#         0.44350988],
#        [0.45238095, 0.19257133, 0.05966654, ..., 0.02188331, 0.8       ,
#         0.32318755]])

# %% [markdown]
# # Data Split

# %%
from sklearn.model_selection import train_test_split 
#Divide the data into training, validation, and testing sets for model development.

# %%
Y= np.squeeze(Y)  
#squeeze() function is used to remove single-dimensional entries from the shape of an array. It returns an array with the same data but reshaped dimensions.

# %%
x_train,x_test,y_train,y_test = train_test_split(X_scale,Y, test_size = 0.2, random_state=42)
#Spliting the data into training and test data in the ratio 80:20 respectively.

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# *Feature selection is a process that chooses a subset of features from the original features so that the feature space is optimally reduced according to a certain criterion.*

# %% [markdown]
# *here, based on correlation coefficient obtained, which is basically a filter technique used in feature reduction and based on the exploratory data analysis performed we choose a subset of features to be trained*

# %%
X.columns # the feature columns is reduced from 27 to 19 features, which is choosen to be trained.
# Out:
# Index(['Age', 'SSN', 'Annual_Income', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Delay_from_due_date',
#        'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_History_Age', 'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Payment_Behaviour', 'Monthly_Balance'],
#       dtype='object')

# %%
X.shape # after upsampling and feature reduction
# Out:
# (77412, 18)

# %% [markdown]
# # Model Selection & Model Evaluation

# %% [markdown]
# # Logistic Regression

# %%
#importing necessary libraries
from sklearn.linear_model import LogisticRegression
#Initialize Logistic Regression model.
#Model Training and optimizing their hyperparameters for improved performance.
lr = LogisticRegression(random_state=42,max_iter=5000)

# %%
#fit the model to the data
model = lr.fit(x_train,y_train)

# %%
#make predictions
y_predictions = model.predict(x_test)

# %%
#importing necessary libraries for model evaluation
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score

# %%
confusion_matrix(y_test,y_predictions) #A confusion matrix is table that define the performance of classification algorithm.
# Out:
# array([[4328,  140,  658],
#        [ 694, 3581,  904],
#        [ 953, 1181, 3044]], dtype=int64)

# %% [markdown]
# *Above matrix aids in analyzing model performance,identifying mis-classifications,and improving*
# *predictive accuracy.*

# %%
#evaluate the model
acc_log = accuracy_score(y_test,y_predictions)
acc_log
# Out:
# 0.7074210424336369

# %%
print("precision =",precision_score(y_test,y_predictions,average="weighted"))
# Out:
# precision = 0.7051863880823039

# %%
print("recall =",recall_score(y_test,y_predictions,average="weighted"))
# Out:
# recall = 0.7074210424336369

# %%
print("f1_score =",f1_score(y_test,y_predictions,average="weighted"))
# Out:
# f1_score = 0.7038916066475641

# %% [markdown]
# # KNeighborsClassifier

# %%
#Importing necessay libraries
from sklearn.neighbors import KNeighborsClassifier

# %%
metric_k =[]

# %%
neighbors = np.arange(3,15)

# %%
#initialize and train the model knn classifier
for k in neighbors:
    classifier = KNeighborsClassifier(n_neighbors =k, metric='euclidean')
    classifier.fit(x_train,y_train)
    y_pred_kn = classifier.predict(x_test)
    acc_kn = accuracy_score(y_test,y_pred_kn)
    metric_k.append(acc_kn)

# %%
metric_k
# Out:
# [0.8212878641090228,
#  0.8135374281469999,
#  0.8059807530840276,
#  0.800684621843312,
#  0.7957760124006975,
#  0.7909965768907834,
#  0.7893173157656785,
#  0.7807918362074533,
#  0.7787896402505974,
#  0.7733643350771814,
#  0.7699412258606213,
#  0.7663243557450107]

# %% [markdown]
# #  Decision Tree Classifier

# %%
#importing necessary libraries
from sklearn.tree import DecisionTreeClassifier

# %%
#Initialize Decision Tree Classifier model.
#Model Training
dt_cls = DecisionTreeClassifier(random_state =42)

# %%
#fit the model to the data
model_dt = dt_cls.fit(x_train,y_train)

# %%
#make predictions
y_pred_dt = model.predict(x_test)

# %%
confusion_matrix(y_test,y_pred_dt)
# Out:
# array([[4328,  140,  658],
#        [ 694, 3581,  904],
#        [ 953, 1181, 3044]], dtype=int64)

# %%
accuracy_score(y_test,y_pred_dt)
# Out:
# 0.7074210424336369

# %%
acc_dt = accuracy_score(y_test,y_pred_dt)

# %%
acc_dt
# Out:
# 0.7074210424336369

# %%
print("precision =",precision_score(y_test,y_pred_dt,average="weighted"))
# Out:
# precision = 0.7051863880823039

# %%
print("recall =",recall_score(y_test,y_pred_dt,average="weighted"))
# Out:
# recall = 0.7074210424336369

# %%
print("f1_score =",f1_score(y_test,y_pred_dt,average="weighted"))
# Out:
# f1_score = 0.7038916066475641

# %% [markdown]
# # Random Forest Classifier

# %%
#importing necessary libraries

from sklearn.ensemble import RandomForestClassifier

# %%
#Initialize Random Forest Classifier model.
#Model Training

rf_cls =RandomForestClassifier()

# %%
#fit the model to the data
model_rf = rf_cls.fit(x_train,y_train)

# %%
#make predicitions
y_pred_rf = model_rf.predict(x_test)

# %%
confusion_matrix(y_test,y_pred_rf)
# Out:
# array([[4800,   31,  295],
#        [  69, 4784,  326],
#        [ 452,  685, 4041]], dtype=int64)

# %%
acc_rf =accuracy_score(y_test,y_pred_rf)

# %%
acc_rf
# Out:
# 0.879997416521346

# %% [markdown]
# *Accuracy is calculated as the number of correct predictions divided by the total number of predictions made by the model.*

# %%
pre_rf =precision_score(y_test,y_pred_rf,average = "weighted")

# %%
pre_rf
# Out:
# 0.8794902789164735

# %% [markdown]
# *Precision tells us how many of the correctly predicted cases actually turned out to be positive.*

# %%
recall_rf =recall_score(y_test,y_pred_rf,average = "weighted")

# %%
recall_rf
# Out:
# 0.879997416521346

# %% [markdown]
# *Recall tells us how many of the actual positive cases we were able to predict correctly with our model.*

# %%
f1_rf =f1_score(y_test,y_pred_rf,average = "weighted")

# %%
f1_rf
# Out:
# 0.878609363160652

# %% [markdown]
# *F1-score is a harmonic mean of Precision and Recall, and so it gives a combined idea about these two metrics.
# It is maximum when Precision is equal to Recall.
# In practice, when we try to increase the precision of our model, the recall goes down, and vice-versa.
# The F1-score captures both the trends in a single value.*

# %% [markdown]
# # Model Performance

# %% [markdown]
# **Generating classification report**
#
# *A classification report is a text summary that shows the main metrics for each class of a machine learning model.
# It includes the precision, recall, F1-score, and support for each class,
# as well as the weighted average of these metrics across all classes.*

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_predictions))
#report on logistic regression classifier
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.84      0.78      5126
#            1       0.73      0.69      0.71      5179
#            2       0.66      0.59      0.62      5178
#
#     accuracy                           0.71     15483
#    macro avg       0.71      0.71      0.70     15483
# weighted avg       0.71      0.71      0.70     15483

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_kn))
#report on KNN classifier
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81      5126
#            1       0.79      0.80      0.79      5179
#            2       0.75      0.63      0.69      5178
#
#     accuracy                           0.77     15483
#    macro avg       0.77      0.77      0.76     15483
# weighted avg       0.77      0.77      0.76     15483

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_dt))
#report on decision tree classifier
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.84      0.78      5126
#            1       0.73      0.69      0.71      5179
#            2       0.66      0.59      0.62      5178
#
#     accuracy                           0.71     15483
#    macro avg       0.71      0.71      0.70     15483
# weighted avg       0.71      0.71      0.70     15483

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_rf))
#report on random forest classifier
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92      5126
#            1       0.87      0.92      0.90      5179
#            2       0.87      0.78      0.82      5178
#
#     accuracy                           0.88     15483
#    macro avg       0.88      0.88      0.88     15483
# weighted avg       0.88      0.88      0.88     15483

# %%
pd.DataFrame([acc_log,acc_kn,acc_dt,acc_rf]).plot.bar();
plt.xticks(np.arange(4),('log_reg',"knn",'DT',"RF"))
plt.legend().remove()
plt.ylim(0,1)
plt.ylabel('Accuracy')
plt.xlabel('Models')
plt.xticks(rotation = 0)
plt.title('Comparing Model Performance');

# %% [markdown]
# **Among the above classification methods, RandomForest Classifier gives higher accuracy and better fit model.**

# %% [markdown]
# # CROSS VALIDATION

# %% [markdown]
# **Dividing the dataset into multiple subsets, using some for training the model and the rest for testing, multiple times to obtain reliable performance metrics.**

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_scores = cross_val_score(rf_cls, x_train, y_train, cv=5, scoring='accuracy')

# %%
print("Average Cross-Validation Accuracy:", cross_val_scores.mean())
# Out:
# Average Cross-Validation Accuracy: 0.8730319925064183

# %% [markdown]
# **From above a reliable performance metrics with accuracy of 0.873 is obtained.**
